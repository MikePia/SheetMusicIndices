# %%
import logging
import csv
import os
import sys
from extractTOC import save_toc_to_csv, get_page_count

# %% [markdown]
# # Tagging Mobile Sheets index files and stuff. This is the code, enter data below

# %%
logger = logging.getLogger()

class MobileIndex:
    fname = None
    dlmtr = ";"
    newcsv = []
    abbrv = ""
    input_dir = ""
    output_dir = ""
    data = []
    total_pages = 0

    def __init__(
        self,
        fname,
        dlmtr,
        output_dir,
        input_dir,
        total_pages,
        abbrv=None,
        collections=None,
        genres=None,
        offset=None,
        composers=None,
        capb=False,
        
    ):
        self.abbrv = abbrv
        self.dlmtr = dlmtr
        self.output_dir = output_dir
        self.input_dir = input_dir
        self.total_pages = total_pages
        self.fname = os.path.join(self.input_dir, fname)
        
        if (
            not os.path.exists(self.input_dir)
            or not os.path.exists(self.output_dir)
            or not os.path.exists(self.fname)
        ):
            raise ValueError("Input or output directory or file does not exist")
        self.out_name = os.path.join(self.output_dir, fname)
        
        # Load the CSV data into self.data
        self.load_csv()

        # Optional adjustments
        if self.abbrv:
            self.tag_the_title()
        self.adjust_pages()
        if collections:
            self.collections = collections
            self.set_collections()
        if genres:
            self.genres = genres
            self.set_genres()
        if composers:
            self.composers = composers
            self.set_composers()
        
        if offset:
            self.begin = offset[0]
            self.offset = offset[1]

    def load_csv(self):
        """Load the CSV data into self.data"""
        with open(self.fname, newline='', encoding='utf-8') as csvfile:
            reader = csv.reader(csvfile, delimiter=self.dlmtr)
            self.data = [row for row in reader]  # Load all rows into self.data

    def tag_the_title(self):
        """Tag the title column with abbreviation"""
        if not self.data:
            return
        
        header = [column.lower() for column in self.data[0]]  # Normalize the header to lowercase
        titleindex = -1
        for row in self.data:
            if titleindex == -1:
                try:
                    titleindex = header.index("title")
                    if titleindex == -1:
                        raise ValueError("Title not found")
                    self.data[0] = header
                except Exception as ex:
                    logger.error("Input file does not have a title header")
                    logger.error(str(ex))
                    logger.error("Exiting program")
                    sys.exit(1)
            elif row[titleindex][0] != "~":  # Skip if starts with "~"
                row[titleindex] += " " + self.abbrv

    def adjust_pages(self):
        """Adjust the pages column by setting each row's 'page'
        to be [current_page]-[next_page - 1], except for the last row,
        which remains singular."""

        if not self.data:
            return

        # 1) Normalize header, find 'pages' column index
        header = [col.lower() for col in self.data[0]]
        page_index = -1

        for i, col in enumerate(header):
            if col == "pages":
                page_index = i
                break
            elif col == "page":
                page_index = i
                header[page_index] = "pages"  # Normalize the header
                self.data[0] = header
                break

        if page_index == -1:
            logger.error("Input file does not have a 'pages' or 'page' header")
            sys.exit(1)

        # 2) Sort by that column
        self.data[1:] = sorted(self.data[1:], key=lambda row: int(row[page_index]))

        # 3) For each row except the last, set range = current_page -> next_page - 1
        #    For the last row, keep it singular.
        for i in range(1, len(self.data) -1):
            current_row = self.data[i]
            next_row = self.data[i + 1]

            current_page = int(current_row[page_index])
            next_page = int(next_row[page_index])

            # If next_page - 1 is >= current_page, create a range
            # Otherwise, it's effectively "current_page-current_page" (which is singular),
            # but from your example, you clearly want something like 9 -> 14 if next is 15,
            # 15 -> 18 if next is 19, etc.
            upper_bound = next_page - 1

            if upper_bound >= current_page:
                current_row[page_index] = f"{current_page}-{upper_bound}"
            else:
                # Means next_page is actually <= current_page
                # so there's no "gap". We'll just keep it singular
                # (or do whatever you prefer in that edge case).
                current_row[page_index] = str(current_page)

        # 4) The last row is left as singular
        self.data[-1][page_index] = f"{int(self.data[-1][page_index])}-{self.total_pages}"
            

        # (Optional) Write out the file
        self.write_csv()


    def write_csv(self):
        """Write the updated data back to the output CSV file"""
        with open(self.out_name, mode='w', newline='', encoding='utf-8') as output_csvfile:
            writer = csv.writer(output_csvfile, delimiter=";")
            writer.writerows(self.data)  # Write the entire data including header

    def set_collections(self):
        """
        Add or update a 'collections' column in self.data with `collection`.
        """

        # Normalize the header to lowercase for searching
        header_lower = [col.lower() for col in self.data[0]]

        # Check if 'collections' already exists in the header
        if 'collections' not in header_lower:
            # Add the column name to the header
            self.data[0].append('collections')
            col_index = len(self.data[0]) - 1
            # Fill each data row with self.collections
            for row in self.data[1:]:
                row.append(self.collections)
        else:
            # If it exists, just update the column in each row
            col_index = header_lower.index('collections')
            for row in self.data[1:]:
                row[col_index] = self.collections


    def set_genres(self):
        """
        Add or update a 'genres' column in self.data with `genres`.
        """

        # Normalize the header to lowercase for searching
        header_lower = [col.lower() for col in self.data[0]]

        # Check if 'genres' already exists
        if 'genres' not in header_lower:
            self.data[0].append('genres')
            col_index = len(self.data[0]) - 1
            for row in self.data[1:]:
                row.append(self.genres)
        else:
            col_index = header_lower.index('genres')
            for row in self.data[1:]:
                row[col_index] = self.genres


    def set_composers(self):
        """
        Add or update a 'composers' column in self.data with `composers`.
        """

        # Normalize the header to lowercase for searching
        header_lower = [col.lower() for col in self.data[0]]

        # Check if 'composers' already exists
        if 'composers' not in header_lower:
            self.data[0].append('composers')
            col_index = len(self.data[0]) - 1
            for row in self.data[1:]:
                row.append(self.composers)
        else:
            col_index = header_lower.index('composers')
            for row in self.data[1:]:
                row[col_index] = self.composers

# %%
fname = 'The Beatles Complete - Vol 1 A-I.csv'
dlmtr = ","
output_dir = '/usr/local/dev/MuApi/SheetMusicIndices/indexes'
input_dir = '/usr/local/dev/MuApi/SheetMusicIndices/origindex/'

abbrv = "[BCV1]"
collections = 'The Beatles Complete'
genres = 'Rock|Pop'
composers = "Lennon/Mcartney, George Harrison"
pdf_file = "/home/mike/Documents/tunes/Beatles/Beatles/The Beatles Complete - Vol 1 A-I.pdf"

# %%
fname = 'The Beatles Complete - Vol 2 I-Z.csv'
pdf_file = "/home/mike/Documents/tunes/Beatles/Beatles/The Beatles Complete - Vol 2 I-Z.pdf"
abbrv = "{BCV2}"

# %%
csv_file = os.path.join(input_dir, fname)
save_toc_to_csv(pdf_file, csv_file)
total_pages = get_page_count(pdf_file)
total_pages
# Out:
# 511

# %%
ms = MobileIndex(
    fname,
    dlmtr,
    output_dir,
    input_dir,
    total_pages,
    abbrv=abbrv,
    genres=genres,
    collections=collections,
    composers=composers,
)
ms.data
ms.write_csv()

# %%
ms.data
# Out:
# [['title', 'level', 'pages', 'collections', 'genres', 'composers'],
#  ['Act Naturally [BCV1]',
#   '1',
#   '9-14',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["All I've Got To Do [BCV1]",
#   '1',
#   '15-18',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Across The Universe [BCV1]',
#   '1',
#   '19-25',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['All My Loving [BCV1]',
#   '1',
#   '26-30',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['All Together Now [BCV1]',
#   '1',
#   '31-38',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['All You Need Is Love [BCV1]',
#   '1',
#   '39-45',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['And I Love Her [BCV1]',
#   '1',
#   '46-50',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['And Your Bird Can Sing [BCV1]',
#   '1',
#   '51-56',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Anna (Go To Him) [BCV1]',
#   '1',
#   '57-63',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Another Girl [BCV1]',
#   '1',
#   '64-68',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Anytime At All [BCV1]',
#   '1',
#   '69-74',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Ask Me Why [BCV1]',
#   '1',
#   '75-82',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["Baby It's You [BCV1]",
#   '1',
#   '83-89',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["Baby, You're A Rich Man [BCV1]",
#   '1',
#   '90-94',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["Baby's In Black [BCV1]",
#   '1',
#   '95-100',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Back In The U.S.S.R. [BCV1]',
#   '1',
#   '101-105',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Bad Boy [BCV1]',
#   '1',
#   '106-112',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['The Ballad Of John And Yoko [BCV1]',
#   '1',
#   '113-117',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Because [BCV1]',
#   '1',
#   '118-122',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Blue Jay Way [BCV1]',
#   '1',
#   '123-129',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Being For The Benefit Of Mr. Kite [BCV1]',
#   '1',
#   '130-137',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Birthday [BCV1]',
#   '1',
#   '138-145',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Blackbird [BCV1]',
#   '1',
#   '146-151',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Boys [BCV1]',
#   '1',
#   '152-157',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["Can't Buy Me Love [BCV1]",
#   '1',
#   '158-163',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Chains [BCV1]',
#   '1',
#   '164-168',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Carry That Weight [BCV1]',
#   '1',
#   '169-173',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Come Together [BCV1]',
#   '1',
#   '174-178',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['The Continuing Story Of Bungalow Bill [BCV1]',
#   '1',
#   '179-183',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Cry Baby Cry [BCV1]',
#   '1',
#   '184-187',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Dear Prudence [BCV1]',
#   '1',
#   '188-194',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Day In The Life, A [BCV1]',
#   '1',
#   '195-202',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Day Tripper [BCV1]',
#   '1',
#   '203-208',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Devil In Her Heart [BCV1]',
#   '1',
#   '209-215',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Dig A Pony [BCV1]',
#   '1',
#   '216-222',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Dig It [BCV1]',
#   '1',
#   '223-227',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Do You Want To Know A Secret? [BCV1]',
#   '1',
#   '228-232',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Dizze Miss Lizzie [BCV1]',
#   '1',
#   '233-238',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Doctor Robot [BCV1]',
#   '1',
#   '239-245',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["Don't Let Me Down [BCV1]",
#   '1',
#   '246-250',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["Don't' Bother Me [BCV1]",
#   '1',
#   '251-258',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["Don't Pass Me By [BCV1]",
#   '1',
#   '259-269',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Drive My Car [BCV1]',
#   '1',
#   '270-274',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Eight Days A Week [BCV1]',
#   '1',
#   '275-280',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Eleanor Rigby [BCV1]',
#   '1',
#   '281-283',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Every Little Thing [BCV1]',
#   '1',
#   '284-288',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['The End [BCV1]',
#   '1',
#   '289-294',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Everybody’s Got Something to Hide Except Me and My Monkey [BCV1]',
#   '1',
#   '295-300',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["Everybody's Try To Be My Baby [BCV1]",
#   '1',
#   '301-309',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Fixing A Hole [BCV1]',
#   '1',
#   '310-316',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Flying [BCV1]',
#   '1',
#   '317-321',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['The Fool On The Hill [BCV1]',
#   '1',
#   '322-326',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['For No One [BCV1]',
#   '1',
#   '327-331',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Girl [BCV1]',
#   '1',
#   '332-339',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['For You Blue [BCV1]',
#   '1',
#   '340-340',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['From Me To You [BCV1]',
#   '1',
#   '341-346',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Get Back [BCV1]',
#   '1',
#   '347-350',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Getting Better [BCV1]',
#   '1',
#   '351-356',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Glass Onion [BCV1]',
#   '1',
#   '357-362',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Golden Slumbers [BCV1]',
#   '1',
#   '363-367',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Good Day Sunshine [BCV1]',
#   '1',
#   '368-372',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Good Morning Good Morning [BCV1]',
#   '1',
#   '373-379',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Good Night [BCV1]',
#   '1',
#   '380-384',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Got To Get You Into My Life [BCV1]',
#   '1',
#   '385-390',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Happiness Is A Warm Gun [BCV1]',
#   '1',
#   '391-398',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["Hard Day's Night, A [BCV1]",
#   '1',
#   '399-405',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Helter Skelter [BCV1]',
#   '1',
#   '406-414',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Hello, Goodbye [BCV1]',
#   '1',
#   '415-420',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Help! [BCV1]',
#   '1',
#   '421-426',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Her Majesty [BCV1]',
#   '1',
#   '427-430',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Here Comes The Sun [BCV1]',
#   '1',
#   '431-436',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["Honey Don't [BCV1]",
#   '1',
#   '437-445',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Here, There And Everywhere [BCV1]',
#   '1',
#   '446-451',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Hey Bulldog [BCV1]',
#   '1',
#   '452-456',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Hey Hey Hey Hey [BCV1]',
#   '1',
#   '457-460',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Honey Pie [BCV1]',
#   '1',
#   '461-467',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Hey Jude [BCV1]',
#   '1',
#   '468-473',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['Hold Me Tight [BCV1]',
#   '1',
#   '474-479',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Call Your Name [BCV1]',
#   '1',
#   '480-486',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Am The Walrus [BCV1]',
#   '1',
#   '487-493',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I Don't Want To Spoil The Party [BCV1]",
#   '1',
#   '494-500',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Feel Fine [BCV1]',
#   '1',
#   '501-505',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Me Mine [BCV1]',
#   '1',
#   '506-510',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Need You [BCV1]',
#   '1',
#   '511-516',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Saw Her Standing There [BCV1]',
#   '1',
#   '517-524',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Should Have Know Better [BCV1]',
#   '1',
#   '525-530',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Wanna Be Your Man [BCV1]',
#   '1',
#   '531-533',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Will [BCV1]',
#   '1',
#   '534-537',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Want to Hold Your Hand [BCV1]',
#   '1',
#   '538-543',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Want To Tell You [BCV1]',
#   '1',
#   '544-549',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['I Want You (She So Heavy) [BCV1]',
#   '1',
#   '550-555',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I'll Be Back [BCV1]",
#   '1',
#   '556-561',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I'll Cry Instead [BCV1]",
#   '1',
#   '562-565',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I'll Get You [BCV1]",
#   '1',
#   '566-570',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I'll Follow The Sun [BCV1]",
#   '1',
#   '571-574',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I'm Down [BCV1]",
#   '1',
#   '575-581',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I'm A Loser [BCV1]",
#   '1',
#   '582-586',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I'm Happy Just To Dance With You [BCV1]",
#   '1',
#   '587-592',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I'm Looking Through You [BCV1]",
#   '1',
#   '593-599',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I'm So Tired [BCV1]",
#   '1',
#   '600-603',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I'm Only Sleeping [BCV1]",
#   '1',
#   '604-608',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I've Got A Feeling [BCV1]",
#   '1',
#   '609-617',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['If I Fell [BCV1]',
#   '1',
#   '618-622',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ["I've Just Seen A Face [BCV1]",
#   '1',
#   '623-628',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['If I Needed Someone [BCV1]',
#   '1',
#   '629-634',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['The Inner Light [BCV1]',
#   '1',
#   '635-639',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison'],
#  ['In My Life [BCV1]',
#   '1',
#   '640-511',
#   'The Beatles Complete',
#   'Rock|Pop',
#   'Lennon/Mcartney, George Harrison']]

# %% [markdown]
# Column formats:
#
# * composers: "Beethoven,  Walter Becker"
# * keys: C|F|G|D
# * genres: Jazz| Christmas
# * instrument: Piano|Saxaphone

# %%
columns = [   
    "title",	
    "pages",	
    "keys",	
    "composers",	
    "genres",
    "instrument",	
    "albums",	
    "artists",	
    "collections",	
    "years",	
    "source_types",	
    "signatures",	
    "tempos",	
    "duration",
]
